# %%
import torch
t_cpu = torch.rand(500,500,500)
# %timeit t_cpu @ t_cpu
# Out:
# 1.34 s ± 119 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
t_gpu = torch.rand(500,500,500).cuda()
# %timeit t_gpu @ t_gpu
