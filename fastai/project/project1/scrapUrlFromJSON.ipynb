# %% [markdown]
# 1) https://serpapi.com/images-results
#
# 2) https://jsoneditoronline.org/
#
# 3) https://www.programiz.com/python-programming/json
#
# 4) Below code to Write a File

# %%
import json

with open('test.json') as f:
  data = json.load(f)
# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
print(data)

for  i in range(100):
  print(data[str(i)]['original'])
  with open('somefile12.txt', 'a') as file:
    file.write(data[str(i)]['original'] + '\n')
# Out:
# {'0': {'position': 1, 'source': 'ironman.fandom.com', 'title': 'Mark LXXXV | Iron Man Wiki | Fandom', 'link': 'https://ironman.fandom.com/wiki/Mark_LXXXV', 'original': 'https://vignette.wikia.nocookie.net/ironman/images/8/89/Iron_man_mark_85.png/revision/latest?cb=20191020193716'}, '1': {'position': 2, 'source': 'shopdisney.com · In stock', 'title': 'Iron Man MK 50 Robot by UBTECH - Marvel ...', 'link': 'https://www.shopdisney.com/iron-man-mk-50-robot-by-ubtech---marvels-avengers-endgame-430614830470.html', 'original': 'https://cdn-ssl.s7.disneystore.com/is/image/DisneyShopping/3061105551624-1'}, '2': {'position': 3, 'source': 'sideshow.com · In stock', 'title': 'Iron Man Mark LXXXV 1/6 Scale Figure ...', 'link': 'https://www.sideshow.com/collectibles/marvel-iron-man-mark-lxxxv-hot-toys-904599', 'original': 'https://www.sideshow.com/storage/product-images/904599/iron-man-mark-lxxxv__silo.png'}, '3': {'position': 4, 'source': 'sideshow.com · In stock', 'title': 'Mark VII 1/6 Scale Fig
# ...
